# %% [markdown]
# # OKOEDE KAROL

# %% [markdown]
# #### PROJECT 1 FLOWCHART

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### PSEUDOCODE

# %%
num = int(input("please any number"))
if num <= 17:
    print(17 - num)
else:
    print((num - 17)*2)

# %% [markdown]
# #### Project 2 flowchart

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### pseudocode

# %%
a = int(input("please input any number"))
b = int(input("please input any number"))
c = int(input("please input any number"))
sum = a + b +c
if a == b == c 
print(sum = sum*3)
else:
    print(sum)

# %% [markdown]
# #### project 3 flowchart

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Pseudocode

# %%
a = int(input(please input any number))
b = int(input(please input any number))
if a == b or abs(a - b) == 5 or (a + b) == 5: 
    return True
else:
    return False

# %% [markdown]
# #### PROJECT FOUR FLOWCHART

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### PSEUDOCODE

# %%
G = int(input("value of i: "))
k = G - 1
while 0 < k:
    print (k*k)
    k = k - 1

# %% [markdown]
# ![image.png](attachment:image.png)
